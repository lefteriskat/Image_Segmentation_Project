# %%
import glob
from PIL import Image
import numpy as np

from pathlib import Path

# %%
data_path = '/dtu/datasets1/02514/PH2_Dataset_images/'
images_path = sorted(glob.glob(data_path+'*'))

# %%
for path_ in images_path:
    print(path_)
    folders_ = glob.glob(path_+'**/*')
    for folder_ in folders_:
        print('\t',folder_)
# Out:
# /dtu/datasets1/02514/PH2_Dataset_images/IMD002
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_Dermoscopic_Image
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_lesion
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_roi
# /dtu/datasets1/02514/PH2_Dataset_images/IMD003
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD003/IMD003_Dermoscopic_Image
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD003/IMD003_lesion
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD003/IMD003_roi
# /dtu/datasets1/02514/PH2_Dataset_images/IMD004
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD004/IMD004_Dermoscopic_Image
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD004/IMD004_lesion
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD004/IMD004_roi
# /dtu/datasets1/02514/PH2_Dataset_images/IMD006
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD006/IMD006_Dermoscopic_Image
# 	 /dtu/datasets1/02514/PH2_Dataset_images/IMD006/IMD006_lesion
# ...

# %%
imgs_paths = list(Path(data_path).iterdir())

# %%
def get_subfolders(root_dir):
    specific_images_dirs = list(Path(root_dir).iterdir())
    return specific_images_dirs

def get_data(data_dir):
    data_dir = sorted(data_dir)
    data_ = []
    names = []
    for data_type in data_dir:
        for file_ in data_dir.glob('*/*.bmp'):
            print(file_)

    return
    data_paths = []
    for data_ in data_dir.glob('*.*'):
        data_paths.append(data_)
    return data_paths

# %%
img_data = get_subfolders(imgs_paths[0])
get_data(img_data)
# Out:
# [PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_Dermoscopic_Image'), PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_lesion'), PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_roi')] [PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_Dermoscopic_Image'), PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_lesion'), PosixPath('/dtu/datasets1/02514/PH2_Dataset_images/IMD002/IMD002_roi')]
